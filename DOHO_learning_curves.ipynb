# %%
import pandas as pd

# %%
path = 'runs-2\content\\runs\detect\\train\\results.csv'
df = pd.read_csv(path)
df
# Out:
#     epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1    34.4738         1.14834         7.17674         0.02006
# 1       2    66.9577         1.13854         5.58285         0.01949
# 2       3    98.3726         1.18203         4.44130         0.02113
# 3       4   130.0510         1.22923         3.46700         0.02132
# 4       5   160.5150         1.20286         2.73273         0.02136
# 5       6   190.7440         1.22817         2.34583         0.02209
# 6       7   222.1730         1.20140         1.98625         0.02154
# 7       8   252.7240         1.20983         1.75816         0.02090
# 8       9   283.6080         1.16208         1.64045         0.02064
# 9      10   314.9300         1.20740         1.59728         0.02091
# 10     11   345.5610         1.17215         1.49372         0.02033
# 11     12   377.3170         1.14986         1.37080         0.02043
# 12     13   407.9530         1.11353         1.26258         0.01931
# ...

# %%
df[['train/box_loss','val/box_loss']].plot()
# Out:
# <Axes: >

# %%
df[['train/cls_loss','val/cls_loss']].plot()
# Out:
# <Axes: >

# %%
df[['train/dfl_loss', 'val/dfl_loss']].plot()
# Out:
# <Axes: >
